# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

df=pd.read_csv('car_data.csv')
ax = df.plot(x='Make',y='MSRP',color='DarkBlue',label='Class1')

plt.show()
# plt.savefig('./try.jpg')
